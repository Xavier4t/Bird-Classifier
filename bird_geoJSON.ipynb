# %% [markdown]
# # Create geoJSON files (test notebook for flask app)

# %%
import os
import json
import geojson
from geojson import FeatureCollection, Feature, Point
import pandas as pd
from pprint import pprint
import numpy as np

# %%
# path constructor
def path_constructor(parent, child):
    return os.path.join(parent, child)

# %%
# data folder
dataFolder = path_constructor("bird_data", "selected_birds")
jsonFolder=path_constructor(dataFolder,"json")
jsonFiles = os.listdir(jsonFolder)
geojsonFolder= path_constructor(dataFolder,"geojson")

# %%
bird_df = pd.read_csv(path_constructor("bird_data", "bird_calls.csv"))
bird_df.head()
# Out:
#                              fname               label
# 0  American_Goldfinch_XC114342.wav  American_Goldfinch
# 1  American_Goldfinch_XC124312.wav  American_Goldfinch
# 2  American_Goldfinch_XC133564.wav  American_Goldfinch
# 3  American_Goldfinch_XC133565.wav  American_Goldfinch
# 4  American_Goldfinch_XC141469.wav  American_Goldfinch

# %%
birdID = bird_df.fname.str[-10:-4]
birdList=list(np.unique(bird_df.label))

# %%
birdList
# Out:
# ['American_Goldfinch',
#  'American_Robin',
#  'Barn_Swallow',
#  'Blue-grey_Gnatcatcher',
#  'Blue_Jay',
#  'Carolina_Chickadee',
#  'Carolina_Wren',
#  'Cedar_Waxwing',
#  'Northern_Cardinal',
#  'Ruby-crowned_Kinglet']

# %%
def openFile(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        data=json.load(f)
    return data

# %%
def birdData(data, birdID):
    datalist = []
    for b in birdID:
        for i in range(len(data['recordings'])):
            if b == data["recordings"][i]["id"]:
                temp=data['recordings'][i]
                datalist.append(temp)
    return datalist

# %%
pathlist=[]
for file in jsonFiles:
    path=path_constructor(jsonFolder, file)
    pathlist.append(path)

# %%
birdDict={}
for path, bird in zip(pathlist,birdList):
    data=openFile(path)
    blist=birdData(data, birdID)
    birdDict[bird]=blist

# %%
def geoBird(chickList):
    bird_keys = ['id', 'en', 'gen', 'sp', 'cnt','loc', 'file', 'date']
    properties=[]
    coordinates = []
    geo = []
    for i in range(len(chickList)):
        prop={k:v for (k,v) in chickList[i].items() if k in bird_keys}
        properties.append(prop)
        lat = chickList[i]["lat"]        
        lng = chickList[i]["lng"]
        if lat != None and lng != None:
            coordinates.append((float(lng),float(lat)))
        
    for pt, prop in zip(coordinates, properties):
        mypoint=Point(pt)
        geo.append(Feature(properties=prop, geometry=mypoint))
    
    feature_collection=FeatureCollection(geo)

    return feature_collection

# %%
def geoBird2(chickList):
    bird_keys = ['id', 'en', 'gen', 'sp', 'cnt','loc', 'date', 'file', 'file-name', "sono"]
    clip_prop = []
    properties=[]
    coordinates = []
    geo = []
    for i in range(len(chickList)):
        prop={k:v for (k,v) in chickList[i].items() if k in bird_keys}
        properties.append(prop)
        lat = chickList[i]["lat"]        
        lng = chickList[i]["lng"]
        if lat != None and lng != None:
            coordinates.append((float(lng),float(lat)))
        
    for pt, prop in zip(coordinates, properties):
        mypoint=Point(pt)
        geo.append(Feature(properties=prop, geometry=mypoint))
    
    feature_collection=FeatureCollection(geo)

    return feature_collection

# %%
test = geoBird2(birdDict['American_Goldfinch'])

# %%
pprint(test)
# Out:
# {'features': [{'geometry': {"coordinates": [-123.546, 48.32], "type": "Point"},
#                'properties': {'cnt': 'Canada',
#                               'date': '2012-08-16',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/114342/download',
#                               'file-name': 'XC114342-amgo.mp3',
#                               'gen': 'Spinus',
#                               'id': '114342',
#                               'loc': 'Rocky Point Bird Observatory, Vancouver '
#                                      'Island, BC ',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC114342-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC114342-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC114342-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC114342-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {"coordinates": [-93.259, 44.942], "type": "Point"},
#                'properties': {'cnt': 'United States',
#                               'date': '2013-03-08',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/124312/download',
#                               'file-name': 'XC124312-JMJ-20130308-063242-0577-USA-MN-Yard-AMGO.mp3',
#                               'gen': 'Spinus',
#                               'id': '124312',
#                               'loc': 'Powderhorn Park, Minneapolis, Hennepin, '
#                                      'Minnesota',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/OJMFAOUBDU/ffts/XC124312-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/OJMFAOUBDU/ffts/XC124312-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/OJMFAOUBDU/ffts/XC124312-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/OJMFAOUBDU/ffts/XC124312-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-74.5269, 40.4746],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2013-05-12',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/133564/download',
#                               'file-name': 'XC133564-Carduelis '
#                                            'tristis130512_T54.mp3',
#                               'gen': 'Spinus',
#                               'id': '133564',
#                               'loc': 'Franklin Township, Somerset, New Jersey',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC133564-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC133564-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC133564-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC133564-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-74.5269, 40.4746],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2013-05-12',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/133565/download',
#                               'file-name': 'XC133565-Carduelis '
#                                            'tristis130512_T55.mp3',
#                               'gen': 'Spinus',
#                               'id': '133565',
#                               'loc': 'Franklin Township, Somerset, New Jersey',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC133565-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC133565-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC133565-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC133565-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-80.9483, 35.1084],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2013-04-08',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/141469/download',
#                               'file-name': 'XC141469-STE-005 partie haute.mp3',
#                               'gen': 'Spinus',
#                               'id': '141469',
#                               'loc': '1, Charlotte (near  Charlotte), '
#                                      'Mecklenburg, North Carolina',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/THHNKSHUMO/ffts/XC141469-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/THHNKSHUMO/ffts/XC141469-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/THHNKSHUMO/ffts/XC141469-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/THHNKSHUMO/ffts/XC141469-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {"coordinates": [-70.668, 41.5221], "type": "Point"},
#                'properties': {'cnt': 'United States',
#                               'date': '2013-05-01',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/153552/download',
#                               'file-name': 'XC153552-American_Goldfinch.mp3',
#                               'gen': 'Spinus',
#                               'id': '153552',
#                               'loc': 'Falmouth, Barnstable, Massachusetts',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/AXWPKDQUXS/ffts/XC153552-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/AXWPKDQUXS/ffts/XC153552-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/AXWPKDQUXS/ffts/XC153552-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/AXWPKDQUXS/ffts/XC153552-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-103.5795, 51.7772],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2013-07-09',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/157457/download',
#                               'file-name': 'XC157457-20130709 090933 amgo male '
#                                            'calls in flight.mp3',
#                               'gen': 'Spinus',
#                               'id': '157457',
#                               'loc': '3 km south of Fishing Lake, Saskatchewan',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC157457-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC157457-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC157457-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC157457-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.37179, 48.576806],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2012-07-07',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/158924/download',
#                               'file-name': 'XC158924-IAC 2012-07-07 '
#                                            'T06-44-32.mp3',
#                               'gen': 'Spinus',
#                               'id': '158924',
#                               'loc': 'Island View Beach Regional Park, Central '
#                                      'Saanich, Vancouver Island, BC',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC158924-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC158924-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC158924-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC158924-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.373425, 48.464413],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2012-07-11',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/158985/download',
#                               'file-name': 'XC158985-IAC 2012-07-11 '
#                                            'T07-07-34.mp3',
#                               'gen': 'Spinus',
#                               'id': '158985',
#                               'loc': 'Swan Lake, Victoria, Vancouver Island, '
#                                      'BC',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC158985-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC158985-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC158985-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC158985-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.546288, 48.319734],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2012-07-24',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/159013/download',
#                               'file-name': 'XC159013-IAC 2012-07-24 (5).mp3',
#                               'gen': 'Spinus',
#                               'id': '159013',
#                               'loc': 'Rocky Point Bird Observatory, Metchosin, '
#                                      'Vancouver Island, BC',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159013-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159013-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159013-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159013-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.546288, 48.319734],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2012-07-24',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/159037/download',
#                               'file-name': 'XC159037-IAC 2012-07-24 (21).mp3',
#                               'gen': 'Spinus',
#                               'id': '159037',
#                               'loc': 'Rocky Point Bird Observatory, Metchosin, '
#                                      'Vancouver Island, BC',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159037-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159037-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159037-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159037-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.546288, 48.319734],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2012-08-13',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/159207/download',
#                               'file-name': 'XC159207-IAC 2012-08-13 T09-06-54 '
#                                            'AMGO.mp3',
#                               'gen': 'Spinus',
#                               'id': '159207',
#                               'loc': 'Rocky Point Bird Observatory, Metchosin, '
#                                      'Vancouver Island, BC',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159207-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159207-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159207-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159207-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.546288, 48.319734],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2012-08-13',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/159209/download',
#                               'file-name': 'XC159209-IAC 2012-08-13 T09-13-08 '
#                                            'amgo.mp3',
#                               'gen': 'Spinus',
#                               'id': '159209',
#                               'loc': 'Rocky Point Bird Observatory, Metchosin, '
#                                      'Vancouver Island, BC',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159209-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159209-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159209-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159209-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.546288, 48.319734],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2012-08-16',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/159240/download',
#                               'file-name': 'XC159240-IAC 2012-08-16 T08-36-34 '
#                                            'amgo.mp3',
#                               'gen': 'Spinus',
#                               'id': '159240',
#                               'loc': 'Rocky Point Bird Observatory, Metchosin, '
#                                      'Vancouver Island, BC',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159240-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159240-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159240-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159240-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.546288, 48.319734],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2012-08-20',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/159284/download',
#                               'file-name': 'XC159284-IAC 2012-08-20 '
#                                            'T09-49-54.mp3',
#                               'gen': 'Spinus',
#                               'id': '159284',
#                               'loc': 'Rocky Point Bird Observatory, Metchosin, '
#                                      'Vancouver Island, BC',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159284-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159284-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159284-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159284-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.546288, 48.319734],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2012-08-20',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/159286/download',
#                               'file-name': 'XC159286-IAC 2012-08-20 T10-02-44 '
#                                            'amgo.mp3',
#                               'gen': 'Spinus',
#                               'id': '159286',
#                               'loc': 'Rocky Point Bird Observatory, Metchosin, '
#                                      'Vancouver Island, BC',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159286-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159286-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159286-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159286-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.546288, 48.319734],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2012-09-14',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/159567/download',
#                               'file-name': 'XC159567-IAC 2012-09-14 '
#                                            'T09-40-30.mp3',
#                               'gen': 'Spinus',
#                               'id': '159567',
#                               'loc': 'Rocky Point Bird Observatory, Metchosin, '
#                                      'Vancouver Island, BC',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159567-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159567-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159567-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159567-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.546288, 48.319734],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2012-09-14',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/159568/download',
#                               'file-name': 'XC159568-IAC 2012-09-14 '
#                                            'T09-41-28.mp3',
#                               'gen': 'Spinus',
#                               'id': '159568',
#                               'loc': 'Rocky Point Bird Observatory, Metchosin, '
#                                      'Vancouver Island, BC',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159568-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159568-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159568-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159568-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.546288, 48.319734],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2012-09-20',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/159604/download',
#                               'file-name': 'XC159604-IAC 2012-09-20 '
#                                            'T09-55-04.mp3',
#                               'gen': 'Spinus',
#                               'id': '159604',
#                               'loc': 'Rocky Point Bird Observatory, Metchosin, '
#                                      'Vancouver Island, BC',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159604-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159604-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159604-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC159604-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-103.58164, 51.77586],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2013-05-28',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/160625/download',
#                               'file-name': 'XC160625-IAC 2013-05-28 T05-42-18 '
#                                            'amgo.mp3',
#                               'gen': 'Spinus',
#                               'id': '160625',
#                               'loc': '3 km south of Fishing Lake, SK',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160625-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160625-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160625-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160625-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-103.58164, 51.77586],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2013-05-28',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/160660/download',
#                               'file-name': 'XC160660-IAC 2013-05-28 '
#                                            'T07-34-06.mp3',
#                               'gen': 'Spinus',
#                               'id': '160660',
#                               'loc': '3 km south of Fishing Lake, SK',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160660-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160660-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160660-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160660-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-103.58164, 51.77586],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2013-05-28',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/160665/download',
#                               'file-name': 'XC160665-IAC 2013-05-28 '
#                                            'T08-48-34.mp3',
#                               'gen': 'Spinus',
#                               'id': '160665',
#                               'loc': '3 km south of Fishing Lake, SK',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160665-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160665-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160665-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160665-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-103.58164, 51.77586],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2013-06-16',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/160788/download',
#                               'file-name': 'XC160788-IAC 2013-06-16 '
#                                            'T15-59-10.mp3',
#                               'gen': 'Spinus',
#                               'id': '160788',
#                               'loc': '3 km south of Fishing Lake, SK',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160788-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160788-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160788-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160788-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-103.58164, 51.77586],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2013-06-16',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/160789/download',
#                               'file-name': 'XC160789-IAC 2013-06-16 T18-20-34 '
#                                            'amgo flight calls song.mp3',
#                               'gen': 'Spinus',
#                               'id': '160789',
#                               'loc': '3 km south of Fishing Lake, SK',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160789-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160789-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160789-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160789-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-103.58164, 51.77586],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2013-06-21',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/160802/download',
#                               'file-name': 'XC160802-IAC 2013-06-21 T17-51-54 '
#                                            'amgo calls song.mp3',
#                               'gen': 'Spinus',
#                               'id': '160802',
#                               'loc': '3 km south of Fishing Lake, SK',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160802-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160802-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160802-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC160802-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-73.8678, 41.1955],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2011-05-30',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/163044/download',
#                               'file-name': 'XC163044-American_Goldfinch_1.mp3',
#                               'gen': 'Spinus',
#                               'id': '163044',
#                               'loc': 'My old yard, Ossining, New York',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/AMMGWAIZWI/ffts/XC163044-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/AMMGWAIZWI/ffts/XC163044-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/AMMGWAIZWI/ffts/XC163044-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/AMMGWAIZWI/ffts/XC163044-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {"coordinates": [-91.186, 30.462], "type": "Point"},
#                'properties': {'cnt': 'United States',
#                               'date': '2014-01-19',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/165034/download',
#                               'file-name': 'XC165034-Carduelis '
#                                            'tristis140119_T688.mp3',
#                               'gen': 'Spinus',
#                               'id': '165034',
#                               'loc': 'Capitol Lake, Baton Rouge, Louisiana',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC165034-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC165034-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC165034-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC165034-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-117.0634, 32.5547],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2013-04-04',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/169080/download',
#                               'file-name': 'XC169080-American Goldfinch -CA, '
#                                            'Dairy Mart Pond, -CA, TRV, April '
#                                            '04, 2013, 1100 AM.mp3',
#                               'gen': 'Spinus',
#                               'id': '169080',
#                               'loc': 'Dairymart Ponds, San Diego County, '
#                                      'California',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169080-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169080-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169080-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169080-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-117.0634, 32.5547],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2013-04-04',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/169081/download',
#                               'file-name': 'XC169081-American Goldfinch -CA, '
#                                            'Dairy Mart Pond, -CA, TRV, April '
#                                            '04, 2013, 1103 AM.mp3',
#                               'gen': 'Spinus',
#                               'id': '169081',
#                               'loc': 'Dairymart Ponds, San Diego County, '
#                                      'California',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169081-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169081-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169081-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169081-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-80.9798, 28.5037],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2014-03-04',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/169083/download',
#                               'file-name': 'XC169083-American Goldfinch not '
#                                            'seen -FL, Tosohatchee, March 04, '
#                                            '2014, 0942 AM.mp3',
#                               'gen': 'Spinus',
#                               'id': '169083',
#                               'loc': 'Tosohatchee Wildlife Management Area, '
#                                      'Orange County, Florida',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169083-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169083-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169083-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169083-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {"coordinates": [-96.861, 28.2366], "type": "Point"},
#                'properties': {'cnt': 'United States',
#                               'date': '2012-02-03',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/169084/download',
#                               'file-name': 'XC169084-American Goldfinch -TX, '
#                                            'Aransas NWR, February 03, '
#                                            '\u200e2012, 0805 AM.mp3',
#                               'gen': 'Spinus',
#                               'id': '169084',
#                               'loc': 'Aransas NWR, Aransas Co, Texas',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169084-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169084-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169084-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/RFTXRYBVBX/ffts/XC169084-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {"coordinates": [-92.962, 44.793], "type": "Point"},
#                'properties': {'cnt': 'United States',
#                               'date': '2014-04-18',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/175254/download',
#                               'file-name': 'XC175254-JMJ-20140418-102908-140418_34-USA-MN-GreyCloudDunes-AMGO.mp3',
#                               'gen': 'Spinus',
#                               'id': '175254',
#                               'loc': 'Grey Cloud Dunes SNA, Washington, '
#                                      'Minnesota',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/OJMFAOUBDU/ffts/XC175254-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/OJMFAOUBDU/ffts/XC175254-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/OJMFAOUBDU/ffts/XC175254-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/OJMFAOUBDU/ffts/XC175254-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {"coordinates": [-76.345, 40.043], "type": "Point"},
#                'properties': {'cnt': 'United States',
#                               'date': '2014-05-01',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/179074/download',
#                               'file-name': 'XC179074-Carduelis '
#                                            'tristis140501_T871.mp3',
#                               'gen': 'Spinus',
#                               'id': '179074',
#                               'loc': 'W Lancaster, Lancaster Co., Pennsylvania',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC179074-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC179074-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC179074-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC179074-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-76.4527, 42.4713],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2014-05-03',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/179092/download',
#                               'file-name': 'XC179092-Carduelis '
#                                            'tristis140503_T883.mp3',
#                               'gen': 'Spinus',
#                               'id': '179092',
#                               'loc': 'Ithaca, Tompkins County, New York',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC179092-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC179092-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC179092-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/WOEAFQRMUD/ffts/XC179092-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-120.8402, 35.344],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2014-05-19',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/179124/download',
#                               'file-name': 'XC179124-18 Morro Bay 051914 '
#                                            'American Goldfinch 256.mp3',
#                               'gen': 'Spinus',
#                               'id': '179124',
#                               'loc': 'Morro Bay, San Luis Obispo, California',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/KGOCOOKTTU/ffts/XC179124-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/KGOCOOKTTU/ffts/XC179124-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/KGOCOOKTTU/ffts/XC179124-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/KGOCOOKTTU/ffts/XC179124-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.5142, 48.386],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2014-05-10',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/182078/download',
#                               'file-name': 'XC182078-IAC 2014-05-10 09-14-08 '
#                                            "amgo song witty's.MP3",
#                               'gen': 'Spinus',
#                               'id': '182078',
#                               'loc': "Witty's Lagoon, Metchosin, Vancouver "
#                                      'Island, BC',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC182078-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC182078-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC182078-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC182078-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-105.0997, 52.199],
#                             'type': 'Point'},
#                'properties': {'cnt': 'Canada',
#                               'date': '2014-05-21',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/182406/download',
#                               'file-name': 'XC182406-IAC 2014-05-21 07-56-52 '
#                                            'amgo fc.mp3',
#                               'gen': 'Spinus',
#                               'id': '182406',
#                               'loc': 'Humboldt, SK',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC182406-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC182406-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC182406-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/XEIROMUDEB/ffts/XC182406-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-73.7851, 41.2879],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2014-08-20',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/192099/download',
#                               'file-name': 'XC192099-Baby American '
#                                            'Goldfinch.mp3',
#                               'gen': 'Spinus',
#                               'id': '192099',
#                               'loc': 'Yorktown (near  Yorktown Heights), '
#                                      'Westchester County, New York',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/DPIOYNLZQT/ffts/XC192099-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/DPIOYNLZQT/ffts/XC192099-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/DPIOYNLZQT/ffts/XC192099-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/DPIOYNLZQT/ffts/XC192099-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-92.0346, 46.7161],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2014-10-22',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/205514/download',
#                               'file-name': 'XC205514-American Goldfinch flight '
# ...
#                'properties': {'cnt': 'United States',
#                               'date': '2019-08-06',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/490815/download',
#                               'file-name': 'XC490815-Goldfinch.mp3',
#                               'gen': 'Spinus',
#                               'id': '490815',
#                               'loc': 'Hawk Rise Sanctuary (near  Linden), '
#                                      'Union County, New Jersey',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC490815-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC490815-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC490815-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC490815-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {"coordinates": [-73.996, 40.451], "type": "Point"},
#                'properties': {'cnt': 'United States',
#                               'date': '2019-08-21',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/493543/download',
#                               'file-name': 'XC493543-Goldfinch2.mp3',
#                               'gen': 'Spinus',
#                               'id': '493543',
#                               'loc': 'Hawk Rise Sanctuary (near  Linden), '
#                                      'Union County, New Jersey',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC493543-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC493543-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC493543-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC493543-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-91.0756, 40.8918],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2019-09-06',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/496109/download',
#                               'file-name': 'XC496109-Goldfinch3.mp3',
#                               'gen': 'Spinus',
#                               'id': '496109',
#                               'loc': 'Lyndhurst, Bergen County, New Jersey',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC496109-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC496109-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC496109-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC496109-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-71.3676, 42.1291],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2019-10-15',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/502629/download',
#                               'file-name': 'XC502629-Goldfinch4.mp3',
#                               'gen': 'Spinus',
#                               'id': '502629',
#                               'loc': 'Hawk Rise Sanctuary (near  Linden), '
#                                      'Union County, New Jersey',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC502629-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC502629-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC502629-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC502629-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-71.3676, 42.1291],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2019-10-25',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/504150/download',
#                               'file-name': 'XC504150-unknown7.mp3',
#                               'gen': 'Spinus',
#                               'id': '504150',
#                               'loc': 'Sandy Hook, Monmouth Co., NJ',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC504150-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC504150-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC504150-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/MGVGHKBMIZ/ffts/XC504150-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.6912, 45.5575],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2019-08-15',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/511440/download',
#                               'file-name': 'XC511440-190815_0655 AMGO 10m Farm '
#                                            '0700 mp3 amp.mp3',
#                               'gen': 'Spinus',
#                               'id': '511440',
#                               'loc': 'Tama (near  Burlington), Des Moines, '
#                                      'Iowa',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/YHKQPPJDVP/ffts/XC511440-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/YHKQPPJDVP/ffts/XC511440-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/YHKQPPJDVP/ffts/XC511440-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/YHKQPPJDVP/ffts/XC511440-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.6912, 45.5575],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2020-03-22',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/537153/download',
#                               'file-name': 'XC537153-200322_0077_AMGO1_wav.wav',
#                               'gen': 'Spinus',
#                               'id': '537153',
#                               'loc': 'Heenan-Menfi Memorial Airport (near  '
#                                      'Norfolk), Norfolk County, Massachusetts',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/WSTGWONJJJ/ffts/XC537153-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/WSTGWONJJJ/ffts/XC537153-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/WSTGWONJJJ/ffts/XC537153-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/WSTGWONJJJ/ffts/XC537153-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.6912, 45.5575],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2020-03-22',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/537161/download',
#                               'file-name': 'XC537161-200322_0077_AMGO2_mp3.mp3',
#                               'gen': 'Spinus',
#                               'id': '537161',
#                               'loc': 'Heenan-Menfi Memorial Airport (near  '
#                                      'Norfolk), Norfolk County, Massachusetts',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/WSTGWONJJJ/ffts/XC537161-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/WSTGWONJJJ/ffts/XC537161-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/WSTGWONJJJ/ffts/XC537161-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/WSTGWONJJJ/ffts/XC537161-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.7352, 45.6123],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2019-07-19',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/543346/download',
#                               'file-name': 'XC543346-AMGO_2019-07-19_North_Portland_OR_1422.mp3',
#                               'gen': 'Spinus',
#                               'id': '543346',
#                               'loc': '2310 North Wygant Street, North '
#                                      'Portland, Multnomah County, Oregon',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543346-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543346-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543346-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543346-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.7352, 45.6123],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2019-07-19',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/543348/download',
#                               'file-name': 'XC543348-AMGO_2019-07-19_North_Portland_OR_1423.mp3',
#                               'gen': 'Spinus',
#                               'id': '543348',
#                               'loc': '2310 North Wygant Street, North '
#                                      'Portland, Multnomah County, Oregon',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543348-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543348-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543348-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543348-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.7352, 45.6123],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2019-07-19',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/543349/download',
#                               'file-name': 'XC543349-AMGO_2019-07-19_North_Portland_OR_1425.mp3',
#                               'gen': 'Spinus',
#                               'id': '543349',
#                               'loc': '2310 North Wygant Street, North '
#                                      'Portland, Multnomah County, Oregon',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543349-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543349-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543349-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543349-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-88.1756, 41.8605],
#                             'type': 'Point'},
#                'properties': {'cnt': 'United States',
#                               'date': '2019-08-31',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/543350/download',
#                               'file-name': 'XC543350-AMGO_2019-08-31_Smith_Bybee_Wetlands_North_Portland_OR_1300.mp3',
#                               'gen': 'Spinus',
#                               'id': '543350',
#                               'loc': 'Smith Bybee Wetlands, North Portland, '
#                                      'Multnomah County, Oregon',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543350-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543350-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543350-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543350-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'},
#               {'geometry': {"coordinates": [-73.1973, 44.468], "type": "Point"},
#                'properties': {'cnt': 'United States',
#                               'date': '2019-08-31',
#                               'en': 'American Goldfinch',
#                               'file': '//www.xeno-canto.org/543351/download',
#                               'file-name': 'XC543351-AMGO_2019-08-31_Smith_Bybee_Wetlands_North_Portland_OR_1530.mp3',
#                               'gen': 'Spinus',
#                               'id': '543351',
#                               'loc': 'Smith Bybee Wetlands, North Portland, '
#                                      'Multnomah County, Oregon',
#                               'sono': {'full': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543351-full.png',
#                                        'large': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543351-large.png',
#                                        'med': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543351-med.png',
#                                        'small': '//www.xeno-canto.org/sounds/uploaded/GVVNEJJEGA/ffts/XC543351-small.png'},
#                               'sp': 'tristis'},
#                'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
def createLink(dictio):
    for i in range(len(dictio.features)):
        L1 = dictio.features[i]['properties']['sono']['full']
        L2 = dictio.features[i]['properties']['file-name']
        lista = L1.split("/")
        audio_link = "http://"+lista[2]+"/"+lista[3]+"/"+lista[4]+"/"+lista[5]+"/"+L2
        dictio.features[i]['properties']['audio'] = audio_link
    for i in range(len(dictio.features)):
        dictio.features[i]['properties'].pop('sono', None)
        dictio.features[i]['properties'].pop('file-name', None)

# %%
def geoBird3(chickList):
    bird_keys = ['id', 'en', 'gen', 'sp', 'cnt','loc', 'date', 'file', 'file-name', "sono"]
    clip_prop = []
    properties=[]
    coordinates = []
    geo = []
    for i in range(len(chickList)):
        prop={k:v for (k,v) in chickList[i].items() if k in bird_keys}
        properties.append(prop)
        lat = chickList[i]["lat"]        
        lng = chickList[i]["lng"]
        if lat != None and lng != None:
            coordinates.append((float(lng),float(lat)))
        
    for pt, prop in zip(coordinates, properties):
        mypoint=Point(pt)
        geo.append(Feature(properties=prop, geometry=mypoint))
    
    feature_collection=FeatureCollection(geo)
    createLink(feature_collection)

    return feature_collection

# %%
for k in birdDict.keys():
    geofile=geoBird3(birdDict[k])
    filepath=path_constructor(geojsonFolder,f'{k}.json')
    with open(filepath, 'w', encoding='utf-8') as f:
        json.dump(geofile,f)
    f.close()
